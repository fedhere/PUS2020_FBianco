# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/PUS2020_FBianco/blob/master/classdemo/PhillyCitiBikes_partiallyFilledNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Bikeshare Data from rideindego.com
#
# The outputs of this notebook have been remove so you can run it cell by cell and see what each line of code does
#
# while the data is open and accessible it is stored in poorly maintained. It is stored in individual files for each quarter from 2016 through 2022 - zipped csv files (but occasionally additional files are indcluded in the compressed zip) and the naming scheme for the files is not systematic, which is very annoying, and also really common.
# I use the ```urllib3``` library to download the page with all the links to the data files and ```BeautifulSoup`` to read the html page and extract the links.
#
# Additionally I use ```os``` and ```glob``` to downlead, and to find and open the data files after I downloaded them.
#
# Later I use ```pandas``` to read the csv files in
#
# For the geospatial analysis I will use
# - ```shapely``` to create points and lines
# - ```geopandas``` to plot
# - ```folium``` for working with leaflet maps
#
# Finally I will import the colormap tools from matplotlib to map colors to variables in my maps

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.8 MB/s
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 37.3 MB/s
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.22-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.6 MB)
#      |████████████████████████████████| 16.6 MB 15.3 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from geopandas) (21.3)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.8/dist-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (2022.9.24)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (22.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (2022.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->geopandas) (3.0.9)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.22 geopandas-0.12.2 munch-2.5.0 pyproj-3.4.0

# %%
# !pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.8/dist-packages (0.12.1.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from folium) (1.21.6)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.8/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (2022.9.24)

# %%
# interacting with hosting site
import urllib3
from bs4 import BeautifulSoup

# getting and reading files
import os
import glob
import pandas as pd

# geospatial analysis 
from shapely.geometry import Point, LineString
import geopandas as gpd
import folium
from folium.plugins import MarkerCluster

# I need to use matplotlib colormaps to map colors to variables' values
import matplotlib
from matplotlib import cm

# %% [markdown]
# # getting the data

# %% [markdown]
# ## get the links

# %%
http = urllib3.PoolManager()
c = http.request('GET', url="https://www.rideindego.com/about/data/")
soup = BeautifulSoup(c.data.decode('utf-8'))
# Out:
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py:842: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn((

# %%
#the webpage with the links
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]><html lang="en-US" class="no-js lt-ie9 lt-ie8 lt-ie7"><![endif]-->\n<!--[if (IE 7)&!(IEMobile)]><html lang="en-US" class="no-js lt-ie9 lt-ie8"><![endif]-->\n<!--[if (IE 8)&!(IEMobile)]><html lang="en-US" class="no-js lt-ie9"><![endif]-->\n<!--[if gt IE 8]><!-->\n<html class="no-js" lang="en-US">\n <!--<![endif]-->\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>\n  <link href="https://bicycletransit.wpenginepowered.com/wp-content/themes/indego/library/images/apple-touch-icon.png" rel="apple-touch-icon"/>\n  <link href="https://bicycletransit.wpenginepowered.com/wp-content/themes/indego/library/images/favicon.png" rel="icon"/>\n  <!--[if IE]>\n\t\t\t<link rel="shortcut icon" href="https://bicycletransit.wpenginepowered.com/wp-content/themes/indego/library/images/favicon.ico">\n\t\t<![endif]-->\n  <meta content="#f01d4f" name="msapplication-TileColor"/>\n  <meta content="https://www.rideindego.com/wp-content/themes/indego/library/images/win8-tile-icon.png" name="msapplication-TileImage"/>\n  <meta content="#121212" name="theme-color"/>\n  <title>\n   Data – Indego\n  </title>\n  <meta content="max-image-preview:large" name="robots"/>\n  <link href="//translate.google.com" rel="dns-prefetch"/>\n  <link href="//js.stripe.com" rel="dns-prefetch"/>\n  <link href="//v0.wordpress.com" rel="dns-prefetch"/>\n  <link href="https://www.rideindego.com/feed/" rel="alternate" title="Indego » Feed" type="application/rss+xml"/>\n  <link href="https://www.rideindego.com/comments/feed/" rel="alternate" title="Indego » Comments Feed" type="application/rss+xml"/>\n  <link href="https://www.rideindego.com/events/?ical=1" rel="alternate" title="Indego » iCal Feed" type="text/calendar"/>\n  <script type="text/javascript">\n   window._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/14.0.0\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/14.0.0\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/www.rideindego.com\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=6.1.1"}};\n/*! This file is auto-generated */\n!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode,e=(p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0),i.toDataURL());return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(p&&p.fillText)switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([129777,127995,8205,129778,127999],[129777,127995,8203,129778,127999])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(e=t.source||{}).concatemoji?c(e.concatemoji):e.wpemoji&&e.twemo ...

# %%
#the list of links
linklist = [link.get('href') for link in soup.find_all('a') 
              if "upload" in link.get('href')]
linklist
# Out:
# ['https://bicycletransit.wpenginepowered.com/wp-content/uploads/2022/12/indego-trips-2022-q3.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2022/07/indego-trips-2022-q2.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2022/04/indego-trips-2022-q1.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2022/01/indego-trips-2021-q4.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2021/10/indego-trips-2021-q3.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2021/07/indego-trips-2021-q2.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2021/04/indego-trips-2021-q1.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2021/01/indego-trips-2020-q4.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2020/10/indego-trips-2020-q3.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2020/08/indego-trips-2020-q2.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2020/04/indego-trips-2020-q1.csv.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2020/01/indego-trips-2019-q4.csv.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2019/10/indego-trips-2019-q3-1.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2019/07/indego-trips-2019-q2.csv.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2019/04/indego-trips-2019-q1.csv.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2019/01/indego-trips-2018-q4.csv.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2019/01/indego-trips-2018-q3.csv.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2018/09/indego-trips-2018-q2.csv.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2018/04/indego-trips-2018-q1.csv.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2018/01/indego-trips-2017-q4.csv.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2015/12/indego-trips-2017-q3.csv.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2017/07/indego_gbfs_trips_Q2_2017.csv.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2017/04/indego_gbfs_trips_Q1_2017.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2017/01/Indego_trips_Q4_2016.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2016/10/Q3_2016_trips.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2016/07/Indego_Trips_2016Q2.zip',
#  'https://bicycletransit.wpenginepowered.com/wp-content/uploads/2016/07/Indego_Trips_2016Q1.zip',
#  'http://bicycletransit.wpenginepowered.com/wp-content/uploads/2016/01/Indego_Trips_2015Q4.zip',
#  'http://bicycletransit.wpenginepowered.com/wp-content/uploads/2016/01/Indego_Trips_2015Q3.zip',
#  'http://bicycletransit.wpenginepowered.com/wp-content/uploads/2016/01/Indego_Trips_2015Q2.zip',
#  'https://www.rideindego.com/wp-content/uploads/2022/12/indego-stations-2022-10-01.csv']

# %% [markdown]
# ## download and read the links

# %%
#downloading each link
for url in linklist:
  os.system("wget " + url)

# %%
#the list of files locally
glob.glob("*rips*")
# Out:
# ['indego-trips-2021-q1.zip',
#  'indego-trips-2019-q3-1.zip',
#  'indego-trips-2020-q2.zip',
#  'Indego_Trips_2015Q4.zip',
#  'indego-trips-2018-q1.csv.zip',
#  'indego_gbfs_trips_Q2_2017.csv.zip',
#  'Q3_2016_trips.zip',
#  'indego-trips-2019-q1.csv.zip',
#  'Indego_trips_Q4_2016.zip',
#  'indego-trips-2021-q2.zip',
#  'indego-trips-2017-q3.csv.zip',
#  'indego-trips-2019-q4.csv.zip',
#  'indego-trips-2022-q2.zip',
#  'indego-trips-2020-q3.zip',
#  'Indego_Trips_2016Q1.zip',
#  'indego-trips-2022-q1.zip',
#  'indego-trips-2020-q4.zip',
#  'indego-trips-2022-q3.zip',
#  'indego_gbfs_trips_Q1_2017.zip',
#  'Indego_Trips_2015Q3.zip',
#  'indego-trips-2017-q4.csv.zip',
#  'indego-trips-2021-q4.zip',
#  'Indego_Trips_2015Q2.zip',
#  'indego-trips-2019-q2.csv.zip',
#  'indego-trips-2018-q2.csv.zip',
#  'indego-trips-2021-q3.zip',
#  'indego-trips-2018-q3.csv.zip',
#  'indego-trips-2020-q1.csv.zip',
#  'Indego_Trips_2016Q2.zip',
#  'indego-trips-2018-q4.csv.zip']

# %%
# read in the csv file - each file is read in into a "dictionary" - the data can then be retrieved by year and quarder:
# e.g. pds[2016][Q1] retrieves the data from 2016 January 1st through 2016 March 31st
pds = {} # prepare the container
for y in range(2015, 2023): #loop over all years
  print(y)
  pds[y] = {}
  _ = [url for url in glob.glob("*rips*") if ("%d"%y in url)]
  for q in range(1, 5):
    print("\t", q)
    try:
      pds[y][q] = pd.read_csv([url for url in _ 
                             if ("Q%d"%q in url) or ("q%d"%q in url)][0])
    except ValueError:
      os.system("unzip " + [url for url in _ 
                             if ("Q%d"%q in url) or ("q%d"%q in url)][0])
      try:
        pds[y][q] = pd.read_csv([url for url in glob.glob("*rips*csv") if (("%d"%y in url) and 
                                (("Q%d"%q in url) or ("q%d"%q in url)))][0])
      except IndexError:
        print("\t\tno data for this quarter")
    except IndexError:
      print("\t\tno data for this quarter")
# Out:
# 2015
# 	 1
# 		no data for this quarter
# 	 2
# 	 3
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 	 4
# 2016
# 	 1
# 	 2
# 	 3
# 	 4
# 2017
# 	 1
# 	 2
# 	 3
# 	 4
# 2018
# 	 1
# 	 2
# 	 3
# 	 4
# 2019
# 	 1
# 	 2
# 	 3
# 	 4
# 2020
# 	 1
# 	 2
# 	 3
# 	 4
# 2021
# 	 1
# 	 2
# 	 3
# 	 4
# 2022
# 	 1
# 	 2
# 	 3
# 	 4
# 		no data for this quarter

# %% [markdown]
# # explore the data

# %%
#get the info for each year and each quarter
for y in pds.keys(): #years look
  for q in pds[y].keys(): #quarter loop
    print(pds[y][q].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119559 entries, 0 to 119558
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              119559 non-null  int64
#  1   duration             119559 non-null  int64
#  2   start_time           119559 non-null  object
#  3   end_time             119559 non-null  object
#  4   start_station_id     119559 non-null  int64
#  5   start_lat            119559 non-null  float64
#  6   start_lon            119559 non-null  float64
#  7   end_station_id       119559 non-null  int64
#  8   end_lat              119559 non-null  float64
#  9   end_lon              119559 non-null  float64
#  10  bike_id              118649 non-null  float64
#  11  plan_duration        119559 non-null  int64
#  12  trip_route_category  119559 non-null  object
#  13  passholder_type      119559 non-null  object
# dtypes: float64(5), int64(5), object(4)
# memory usage: 12.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188368 entries, 0 to 188367
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              188368 non-null  int64
#  1   duration             188368 non-null  int64
#  2   start_time           188368 non-null  object
#  3   end_time             188368 non-null  object
#  4   start_station_id     188368 non-null  int64
#  5   start_lat            188368 non-null  float64
#  6   start_lon            188368 non-null  float64
#  7   end_station_id       188368 non-null  int64
#  8   end_lat              188368 non-null  float64
#  9   end_lon              188368 non-null  float64
#  10  bike_id              188368 non-null  object
#  11  plan_duration        188368 non-null  int64
#  12  trip_route_category  188368 non-null  object
#  13  passholder_type      188368 non-null  object
# dtypes: float64(4), int64(5), object(5)
# memory usage: 20.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121783 entries, 0 to 121782
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              121783 non-null  int64
#  1   duration             121783 non-null  int64
#  2   start_time           121783 non-null  object
#  3   end_time             121783 non-null  object
#  4   start_station_id     121783 non-null  int64
#  5   start_lat            121783 non-null  float64
#  6   start_lon            121783 non-null  float64
#  7   end_station_id       121783 non-null  int64
#  8   end_lat              121783 non-null  float64
#  9   end_lon              121783 non-null  float64
#  10  bike_id              121783 non-null  int64
#  11  plan_duration        121783 non-null  int64
#  12  trip_route_category  121783 non-null  object
#  13  passholder_type      121783 non-null  object
# dtypes: float64(4), int64(6), object(4)
# memory usage: 13.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73169 entries, 0 to 73168
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   trip_id              73169 non-null  int64
#  1   duration             73169 non-null  int64
#  2   start_time           73169 non-null  object
#  3   end_time             73169 non-null  object
#  4   start_station_id     73159 non-null  float64
#  5   start_lat            73159 non-null  float64
#  6   start_lon            73159 non-null  float64
#  7   end_station_id       73169 non-null  int64
#  8   end_lat              73169 non-null  float64
#  9   end_lon              73169 non-null  float64
#  10  bike_id              73169 non-null  int64
#  11  plan_duration        73169 non-null  int64
#  12  trip_route_category  73169 non-null  object
#  13  passholder_type      73169 non-null  object
# dtypes: float64(5), int64(5), object(4)
# memory usage: 7.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170824 entries, 0 to 170823
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              170824 non-null  int64
#  1   duration             170824 non-null  int64
#  2   start_time           170824 non-null  object
#  3   end_time             170824 non-null  object
#  4   start_station_id     170824 non-null  int64
#  5   start_lat            170824 non-null  float64
#  6   start_lon            170824 non-null  float64
#  7   end_station_id       170824 non-null  int64
#  8   end_lat              170824 non-null  float64
#  9   end_lon              170824 non-null  float64
#  10  bike_id              170824 non-null  int64
#  11  plan_duration        170824 non-null  int64
#  12  trip_route_category  170824 non-null  object
#  13  passholder_type      170824 non-null  object
# dtypes: float64(4), int64(6), object(4)
# memory usage: 18.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234946 entries, 0 to 234945
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              234946 non-null  int64
#  1   duration             234946 non-null  int64
#  2   start_time           234946 non-null  object
#  3   end_time             234946 non-null  object
#  4   start_station_id     234946 non-null  int64
#  5   start_lat            234946 non-null  object
#  6   start_lon            234946 non-null  object
#  7   end_station_id       234946 non-null  int64
#  8   end_lat              234946 non-null  object
#  9   end_lon              234946 non-null  object
#  10  bike_id              234946 non-null  int64
#  11  plan_duration        234946 non-null  int64
#  12  trip_route_category  234946 non-null  object
#  13  passholder_type      234946 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 25.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176119 entries, 0 to 176118
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              176119 non-null  int64
#  1   duration             176119 non-null  int64
#  2   start_time           176119 non-null  object
#  3   end_time             176119 non-null  object
#  4   start_station_id     176119 non-null  int64
#  5   start_lat            176112 non-null  float64
#  6   start_lon            176112 non-null  float64
#  7   end_station_id       176119 non-null  int64
#  8   end_lat              174528 non-null  float64
#  9   end_lon              174528 non-null  float64
#  10  bike_id              176119 non-null  int64
#  11  plan_duration        176119 non-null  int64
#  12  trip_route_category  176119 non-null  object
#  13  passholder_type      176119 non-null  object
# dtypes: float64(4), int64(6), object(4)
# memory usage: 18.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107772 entries, 0 to 107771
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              107772 non-null  int64
#  1   duration             107772 non-null  int64
#  2   start_time           107772 non-null  object
#  3   end_time             107772 non-null  object
#  4   start_station_id     107772 non-null  int64
#  5   start_lat            107758 non-null  float64
#  6   start_lon            107758 non-null  float64
#  7   end_station_id       107772 non-null  int64
#  8   end_lat              106662 non-null  float64
#  9   end_lon              106662 non-null  float64
#  10  bike_id              107772 non-null  int64
#  11  plan_duration        107772 non-null  int64
#  12  trip_route_category  107772 non-null  object
#  13  passholder_type      107772 non-null  object
# dtypes: float64(4), int64(6), object(4)
# memory usage: 11.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220441 entries, 0 to 220440
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              220441 non-null  int64
#  1   duration             220441 non-null  int64
#  2   start_time           220441 non-null  object
#  3   end_time             220441 non-null  object
#  4   start_station        220441 non-null  int64
#  5   start_lat            220399 non-null  float64
#  6   start_lon            220399 non-null  float64
#  7   end_station          220441 non-null  int64
#  8   end_lat              218743 non-null  float64
#  9   end_lon              218743 non-null  float64
#  10  bike_id              220441 non-null  int64
#  11  plan_duration        220441 non-null  int64
#  12  trip_route_category  220441 non-null  object
#  13  passholder_type      220441 non-null  object
# dtypes: float64(4), int64(6), object(4)
# memory usage: 23.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276785 entries, 0 to 276784
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              276785 non-null  int64
#  1   duration             276785 non-null  int64
#  2   start_time           276785 non-null  object
#  3   end_time             276785 non-null  object
#  4   start_station        276785 non-null  int64
#  5   start_lat            276752 non-null  float64
#  6   start_lon            276752 non-null  float64
#  7   end_station          276785 non-null  int64
#  8   end_lat              274828 non-null  float64
#  9   end_lon              274828 non-null  float64
#  10  bike_id              276785 non-null  int64
#  11  plan_duration        276785 non-null  int64
#  12  trip_route_category  276785 non-null  object
#  13  passholder_type      276785 non-null  object
# dtypes: float64(4), int64(6), object(4)
# memory usage: 29.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183909 entries, 0 to 183908
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              183909 non-null  int64
#  1   duration             183909 non-null  int64
#  2   start_time           183909 non-null  object
#  3   end_time             183909 non-null  object
#  4   start_station        183909 non-null  int64
#  5   start_lat            183888 non-null  float64
#  6   start_lon            183888 non-null  float64
#  7   end_station          183909 non-null  int64
#  8   end_lat              182419 non-null  float64
#  9   end_lon              182419 non-null  float64
#  10  bike_id              183909 non-null  int64
#  11  plan_duration        183909 non-null  int64
#  12  trip_route_category  183909 non-null  object
#  13  passholder_type      183909 non-null  object
# dtypes: float64(4), int64(6), object(4)
# memory usage: 19.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98993 entries, 0 to 98992
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   trip_id              98993 non-null  int64
#  1   duration             98993 non-null  int64
#  2   start_time           98993 non-null  object
#  3   end_time             98993 non-null  object
#  4   start_station        98993 non-null  int64
#  5   start_lat            98985 non-null  float64
#  6   start_lon            98985 non-null  float64
#  7   end_station          98993 non-null  int64
#  8   end_lat              97830 non-null  float64
#  9   end_lon              97830 non-null  float64
#  10  bike_id              98993 non-null  int64
#  11  plan_duration        98993 non-null  int64
#  12  trip_route_category  98993 non-null  object
#  13  passholder_type      98993 non-null  object
# dtypes: float64(4), int64(6), object(4)
# memory usage: 10.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201624 entries, 0 to 201623
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              201624 non-null  int64
#  1   duration             201624 non-null  int64
#  2   start_time           201624 non-null  object
#  3   end_time             201624 non-null  object
#  4   start_station        201624 non-null  int64
#  5   start_lat            201581 non-null  float64
#  6   start_lon            201581 non-null  float64
#  7   end_station          201624 non-null  int64
#  8   end_lat              199879 non-null  float64
#  9   end_lon              199879 non-null  float64
#  10  bike_id              201624 non-null  int64
#  11  plan_duration        201624 non-null  int64
#  12  trip_route_category  201624 non-null  object
#  13  passholder_type      201624 non-null  object
# dtypes: float64(4), int64(6), object(4)
# memory usage: 21.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228329 entries, 0 to 228328
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              228329 non-null  int64
#  1   duration             228329 non-null  int64
#  2   start_time           228329 non-null  object
#  3   end_time             228329 non-null  object
#  4   start_station        228329 non-null  int64
#  5   start_lat            228318 non-null  float64
#  6   start_lon            228318 non-null  float64
#  7   end_station          228329 non-null  int64
#  8   end_lat              225767 non-null  float64
#  9   end_lon              225767 non-null  float64
#  10  bike_id              228329 non-null  int64
#  11  plan_duration        228329 non-null  int64
#  12  trip_route_category  228329 non-null  object
#  13  passholder_type      228329 non-null  object
#  14  bike_type            228329 non-null  object
# dtypes: float64(4), int64(6), object(5)
# memory usage: 26.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142872 entries, 0 to 142871
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              142872 non-null  int64
#  1   duration             142872 non-null  int64
#  2   start_time           142872 non-null  object
#  3   end_time             142872 non-null  object
#  4   start_station        142872 non-null  int64
#  5   start_lat            142870 non-null  float64
#  6   start_lon            142870 non-null  float64
#  7   end_station          142872 non-null  int64
#  8   end_lat              140426 non-null  float64
#  9   end_lon              140426 non-null  float64
#  10  bike_id              142872 non-null  object
#  11  plan_duration        142872 non-null  int64
#  12  trip_route_category  142872 non-null  object
#  13  passholder_type      142872 non-null  object
#  14  bike_type            142872 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 16.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96593 entries, 0 to 96592
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   trip_id              96593 non-null  int64
#  1   duration             96593 non-null  int64
#  2   start_time           96593 non-null  object
#  3   end_time             96593 non-null  object
#  4   start_station        96593 non-null  int64
#  5   start_lat            96593 non-null  float64
#  6   start_lon            96593 non-null  float64
#  7   end_station          96593 non-null  int64
#  8   end_lat              95062 non-null  float64
#  9   end_lon              95062 non-null  float64
#  10  bike_id              96593 non-null  int64
#  11  plan_duration        96593 non-null  int64
#  12  trip_route_category  96593 non-null  object
#  13  passholder_type      96593 non-null  object
#  14  bike_type            96593 non-null  object
# dtypes: float64(4), int64(6), object(5)
# memory usage: 11.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206354 entries, 0 to 206353
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              206354 non-null  int64
#  1   duration             206354 non-null  int64
#  2   start_time           206354 non-null  object
#  3   end_time             206354 non-null  object
#  4   start_station        206354 non-null  int64
#  5   start_lat            206325 non-null  float64
#  6   start_lon            206325 non-null  float64
#  7   end_station          206354 non-null  int64
#  8   end_lat              203741 non-null  float64
#  9   end_lon              203741 non-null  float64
#  10  bike_id              206354 non-null  int64
#  11  plan_duration        206347 non-null  float64
#  12  trip_route_category  206354 non-null  object
#  13  passholder_type      206319 non-null  object
#  14  bike_type            206354 non-null  object
# dtypes: float64(5), int64(5), object(5)
# memory usage: 23.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275197 entries, 0 to 275196
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              275197 non-null  int64
#  1   duration             275197 non-null  int64
#  2   start_time           275197 non-null  object
#  3   end_time             275197 non-null  object
#  4   start_station        275197 non-null  int64
#  5   start_lat            274847 non-null  float64
#  6   start_lon            274847 non-null  float64
#  7   end_station          275197 non-null  int64
#  8   end_lat              271753 non-null  float64
#  9   end_lon              271753 non-null  float64
#  10  bike_id              275197 non-null  int64
#  11  plan_duration        275197 non-null  int64
#  12  trip_route_category  275197 non-null  object
#  13  passholder_type      275197 non-null  object
#  14  bike_type            275197 non-null  object
# dtypes: float64(4), int64(6), object(5)
# memory usage: 31.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166116 entries, 0 to 166115
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              166116 non-null  int64
#  1   duration             166116 non-null  int64
#  2   start_time           166116 non-null  object
#  3   end_time             166116 non-null  object
#  4   start_station        166116 non-null  int64
#  5   start_lat            166072 non-null  float64
#  6   start_lon            166072 non-null  float64
#  7   end_station          166116 non-null  int64
#  8   end_lat              163446 non-null  float64
#  9   end_lon              163446 non-null  float64
#  10  bike_id              166116 non-null  int64
#  11  plan_duration        166116 non-null  int64
#  12  trip_route_category  166116 non-null  object
#  13  passholder_type      166116 non-null  object
#  14  bike_type            166116 non-null  object
# dtypes: float64(4), int64(6), object(5)
# memory usage: 19.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118190 entries, 0 to 118189
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              118190 non-null  int64
#  1   duration             118190 non-null  int64
#  2   start_time           118190 non-null  object
#  3   end_time             118190 non-null  object
#  4   start_station        118190 non-null  int64
#  5   start_lat            118175 non-null  float64
#  6   start_lon            118175 non-null  float64
#  7   end_station          118190 non-null  int64
#  8   end_lat              116063 non-null  float64
#  9   end_lon              116063 non-null  float64
#  10  bike_id              118190 non-null  int64
#  11  plan_duration        118190 non-null  int64
#  12  trip_route_category  118190 non-null  object
#  13  passholder_type      118190 non-null  object
#  14  bike_type            118190 non-null  object
# dtypes: float64(4), int64(6), object(5)
# memory usage: 13.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186586 entries, 0 to 186585
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              186586 non-null  int64
#  1   duration             186586 non-null  int64
#  2   start_time           186586 non-null  object
#  3   end_time             186586 non-null  object
#  4   start_station        186586 non-null  int64
#  5   start_lat            186581 non-null  float64
#  6   start_lon            186581 non-null  float64
#  7   end_station          186586 non-null  int64
#  8   end_lat              183424 non-null  float64
#  9   end_lon              183424 non-null  float64
#  10  bike_id              186586 non-null  int64
#  11  plan_duration        186586 non-null  int64
#  12  trip_route_category  186586 non-null  object
#  13  passholder_type      186586 non-null  object
#  14  bike_type            186586 non-null  object
# dtypes: float64(4), int64(6), object(5)
# memory usage: 21.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269985 entries, 0 to 269984
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              269985 non-null  int64
#  1   duration             269985 non-null  int64
#  2   start_time           269985 non-null  object
#  3   end_time             269985 non-null  object
#  4   start_station        269985 non-null  int64
#  5   start_lat            269983 non-null  float64
#  6   start_lon            269983 non-null  float64
#  7   end_station          269985 non-null  int64
#  8   end_lat              264365 non-null  float64
#  9   end_lon              264365 non-null  float64
#  10  bike_id              269985 non-null  object
#  11  plan_duration        269985 non-null  int64
#  12  trip_route_category  269985 non-null  object
#  13  passholder_type      269985 non-null  object
#  14  bike_type            269985 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 30.9+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160401 entries, 0 to 160400
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              160401 non-null  int64
#  1   duration             160401 non-null  int64
#  2   start_time           160401 non-null  object
#  3   end_time             160401 non-null  object
#  4   start_station        160401 non-null  int64
#  5   start_lat            160398 non-null  float64
#  6   start_lon            160398 non-null  float64
#  7   end_station          160401 non-null  int64
#  8   end_lat              156753 non-null  float64
#  9   end_lon              156753 non-null  float64
#  10  bike_id              160401 non-null  object
#  11  plan_duration        160401 non-null  int64
#  12  trip_route_category  160401 non-null  object
#  13  passholder_type      160401 non-null  object
#  14  bike_type            160401 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 18.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96281 entries, 0 to 96280
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   trip_id              96281 non-null  int64
#  1   duration             96281 non-null  int64
#  2   start_time           96281 non-null  object
#  3   end_time             96281 non-null  object
#  4   start_station        96281 non-null  int64
#  5   start_lat            96276 non-null  float64
#  6   start_lon            96276 non-null  float64
#  7   end_station          96281 non-null  int64
#  8   end_lat              93778 non-null  float64
#  9   end_lon              93778 non-null  float64
#  10  bike_id              96281 non-null  object
#  11  plan_duration        96281 non-null  int64
#  12  trip_route_category  96281 non-null  object
#  13  passholder_type      96280 non-null  object
#  14  bike_type            96281 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 11.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232195 entries, 0 to 232194
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              232195 non-null  int64
#  1   duration             232195 non-null  int64
#  2   start_time           232195 non-null  object
#  3   end_time             232195 non-null  object
#  4   start_station        232195 non-null  int64
#  5   start_lat            232189 non-null  float64
#  6   start_lon            232189 non-null  float64
#  7   end_station          232195 non-null  int64
#  8   end_lat              227807 non-null  float64
#  9   end_lon              227807 non-null  float64
#  10  bike_id              232195 non-null  object
#  11  plan_duration        232195 non-null  int64
#  12  trip_route_category  232195 non-null  object
#  13  passholder_type      232195 non-null  object
#  14  bike_type            232195 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 26.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300432 entries, 0 to 300431
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              300432 non-null  int64
#  1   duration             300432 non-null  int64
#  2   start_time           300432 non-null  object
#  3   end_time             300432 non-null  object
#  4   start_station        300432 non-null  int64
#  5   start_lat            300412 non-null  float64
#  6   start_lon            300412 non-null  float64
#  7   end_station          300432 non-null  int64
#  8   end_lat              296273 non-null  float64
#  9   end_lon              296273 non-null  float64
#  10  bike_id              300432 non-null  object
#  11  plan_duration        300432 non-null  int64
#  12  trip_route_category  300432 non-null  object
#  13  passholder_type      300432 non-null  object
#  14  bike_type            300432 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 34.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330220 entries, 0 to 330219
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              330220 non-null  int64
#  1   duration             330220 non-null  int64
#  2   start_time           330220 non-null  object
#  3   end_time             330220 non-null  object
#  4   start_station        330220 non-null  int64
#  5   start_lat            330216 non-null  float64
#  6   start_lon            330216 non-null  float64
#  7   end_station          330220 non-null  int64
#  8   end_lat              325675 non-null  float64
#  9   end_lon              325675 non-null  float64
#  10  bike_id              330220 non-null  object
#  11  plan_duration        330220 non-null  int64
#  12  trip_route_category  330220 non-null  object
#  13  passholder_type      330220 non-null  object
#  14  bike_type            330220 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 37.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129073 entries, 0 to 129072
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              129073 non-null  int64
#  1   duration             129073 non-null  int64
#  2   start_time           129073 non-null  object
#  3   end_time             129073 non-null  object
#  4   start_station        129073 non-null  int64
#  5   start_lat            129053 non-null  float64
#  6   start_lon            129053 non-null  float64
#  7   end_station          129073 non-null  int64
#  8   end_lat              126654 non-null  float64
#  9   end_lon              126654 non-null  float64
#  10  bike_id              129073 non-null  object
#  11  plan_duration        129073 non-null  int64
#  12  trip_route_category  129073 non-null  object
#  13  passholder_type      129073 non-null  object
#  14  bike_type            129073 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 14.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257350 entries, 0 to 257349
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              257350 non-null  int64
#  1   duration             257350 non-null  int64
#  2   start_time           257350 non-null  object
#  3   end_time             257350 non-null  object
#  4   start_station        257350 non-null  int64
#  5   start_lat            257347 non-null  float64
#  6   start_lon            257347 non-null  float64
#  7   end_station          257350 non-null  int64
#  8   end_lat              253259 non-null  float64
#  9   end_lon              253259 non-null  float64
#  10  bike_id              257350 non-null  int64
#  11  plan_duration        257350 non-null  int64
#  12  trip_route_category  257350 non-null  object
#  13  passholder_type      257350 non-null  object
#  14  bike_type            257350 non-null  object
# dtypes: float64(4), int64(6), object(5)
# memory usage: 29.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312379 entries, 0 to 312378
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   trip_id              312379 non-null  int64
#  1   duration             312379 non-null  int64
#  2   start_time           312379 non-null  object
#  3   end_time             312379 non-null  object
#  4   start_station        312379 non-null  int64
#  5   start_lat            312372 non-null  float64
#  6   start_lon            312372 non-null  float64
#  7   end_station          312379 non-null  int64
#  8   end_lat              307807 non-null  float64
#  9   end_lon              307807 non-null  float64
#  10  bike_id              312379 non-null  object
#  11  plan_duration        312379 non-null  int64
#  12  trip_route_category  312379 non-null  object
#  13  passholder_type      312336 non-null  object
#  14  bike_type            312379 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 35.7+ MB
# None

# %%
#get the number of rows and columns for each year and quarter
for y in pds.keys(): #year loop
  for q in pds[y].keys(): #quarter loop
    print(y, "Q%d"%q, ("(rows, columns)"), pds[y][q].shape)
# Out:
# 2015 Q2 (rows, columns) (119559, 14)
# 2015 Q3 (rows, columns) (188368, 14)
# 2015 Q4 (rows, columns) (121783, 14)
# 2016 Q1 (rows, columns) (73169, 14)
# 2016 Q2 (rows, columns) (170824, 14)
# 2016 Q3 (rows, columns) (234946, 14)
# 2016 Q4 (rows, columns) (176119, 14)
# 2017 Q1 (rows, columns) (107772, 14)
# 2017 Q2 (rows, columns) (220441, 14)
# 2017 Q3 (rows, columns) (276785, 14)
# 2017 Q4 (rows, columns) (183909, 14)
# 2018 Q1 (rows, columns) (98993, 14)
# 2018 Q2 (rows, columns) (201624, 14)
# 2018 Q3 (rows, columns) (228329, 15)
# 2018 Q4 (rows, columns) (142872, 15)
# 2019 Q1 (rows, columns) (96593, 15)
# 2019 Q2 (rows, columns) (206354, 15)
# 2019 Q3 (rows, columns) (275197, 15)
# 2019 Q4 (rows, columns) (166116, 15)
# 2020 Q1 (rows, columns) (118190, 15)
# 2020 Q2 (rows, columns) (186586, 15)
# 2020 Q3 (rows, columns) (269985, 15)
# 2020 Q4 (rows, columns) (160401, 15)
# 2021 Q1 (rows, columns) (96281, 15)
# 2021 Q2 (rows, columns) (232195, 15)
# 2021 Q3 (rows, columns) (300432, 15)
# 2021 Q4 (rows, columns) (330220, 15)
# 2022 Q1 (rows, columns) (129073, 15)
# 2022 Q2 (rows, columns) (257350, 15)
# 2022 Q3 (rows, columns) (312379, 15)

# %%
# an example of a file # 2022-July thorugh 2022-September
pds[2021][3].head()
# Out:
#      trip_id  duration     start_time       end_time  start_station  \
# 0  398698761        11  7/1/2021 0:00  7/1/2021 0:11           3045
# 1  398698759         4  7/1/2021 0:02  7/1/2021 0:06           3052
# 2  398698757        56  7/1/2021 0:03  7/1/2021 0:59           3192
# 3  398698755        55  7/1/2021 0:04  7/1/2021 0:59           3192
# 4  398698753         5  7/1/2021 0:08  7/1/2021 0:13           3052
#
#    start_lat  start_lon  end_station    end_lat    end_lon bike_id  \
# 0  39.947922 -75.162369         3030  39.939350 -75.157158    3360
# 1  39.947319 -75.156952         3238  39.946281 -75.151382    5420
# 2  39.962070 -75.141113         3161  39.954861 -75.180908   18450
# 3  39.962070 -75.141113         3161  39.954861 -75.180908   16508
# 4  39.947319 -75.156952         3046  39.950119 -75.144722    3475
#
#    plan_duration trip_route_category passholder_type bike_type
# 0             30             One Way        Indego30  standard
# 1             30             One Way        Indego30  standard
# 2             30             One Way        Indego30  electric
# 3             30             One Way        Indego30  electric
# 4            365             One Way       Indego365  standard

# %%
pds[2021][3].describe()
# Out:
#             trip_id       duration  start_station      start_lat  \
# count  3.004320e+05  300432.000000  300432.000000  300412.000000
# mean   4.134962e+08      18.858880    3103.809827      39.952136
# std    8.603314e+06      48.931549      73.620408       0.012410
# min    3.986987e+08       1.000000    3000.000000      39.889938
# 25%    4.058970e+08       7.000000    3040.000000      39.945610
# 50%    4.135417e+08      11.000000    3078.000000      39.951340
# 75%    4.211006e+08      19.000000    3168.000000      39.959240
# max    4.286479e+08    1440.000000    3256.000000      39.991791
#
#            start_lon    end_station        end_lat        end_lon  \
# count  300412.000000  300432.000000  296273.000000  296273.000000
# mean      -75.169267    3102.941684      39.951943     -75.169025
# std         0.016551      74.181687       0.012462       0.016559
# min       -75.226372    3000.000000      39.889938     -75.226372
# 25%       -75.179710    3039.000000      39.945610     -75.179710
# 50%       -75.167831    3077.000000      39.951340     -75.167580
# 75%       -75.158882    3168.000000      39.959229     -75.158211
# max       -75.129936    3256.000000      39.991791     -75.129936
#
#        plan_duration
# count  300432.000000
# mean       77.623655
# std       122.491870
# min         1.000000
# 25%        30.000000
# 50%        30.000000
# 75%        30.000000
# max       365.000000

# %% [markdown]
# # data preprocessing

# %% [markdown]
# convert date column to a datetime object

# %%
pds[2021][3]["start_date"] = pd.to_datetime(pds[2021][3]["start_time"]).dt.date

# %% [markdown]
# create shapely points (```shapely.Point```) from the latitude-longitude values of the start station for each trip
#
# note that I use the ```df.apply()``` method which is a method of the dataframes that applies a function to each row in the dataframe sequentially.
#
# The function is created in place with the ```lambda``` methods:
#
# ```lambda x : x/2```
# is equivalent to
#
# ```
# def func(x):
# return x/2
# ```
#
# so the function im applying is
#
# ```
# Point(longitude, latitude)
# ```

# %%
# create a point from the latitude-longitude values of the start of the trip
pds[2021][3]["startlonlat"] = pds[2021][3][["start_lon", "start_lat"]].apply(lambda x: 
                          Point(x['start_lon'], x['start_lat']), axis=1)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/dtypes/cast.py:118: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
# create a point from the latitude-longitude values of the end of the trip
pds[2021][3]["endlonlat"] = pds[2021][3][["end_lon", "end_lat"]].apply(lambda x: 
                          Point(x['end_lon'], x['end_lat']), axis=1)

# %% [markdown]
# I try to create a line between the start and end trip points for each trip, but this fails because some rows have incorrect lat-long value pairs

# %%
# create a line between the start and end positions... not so easy!
pds[2021][3][["startlonlat", "endlonlat"]].apply(lambda x:
              LineString([x["startlonlat"], x["endlonlat"]]), axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/shapely/speedups/_speedups.pyx in shapely.speedups._speedups.geos_linestring_from_py()
#
# AttributeError: 'list' object has no attribute '__array_interface__'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-f61fbbad2d10> in <module>
#       1 # create a line between the start and end positions... not so easy!
# ----> 2 pds[2021][3][["startlonlat", "endlonlat"]].apply(lambda x:
#       3               LineString([x["startlonlat"], x["endlonlat"]]), axis=1)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-18-f61fbbad2d10> in <lambda>(x)
#       1 # create a line between the start and end positions... not so easy!
#       2 pds[2021][3][["startlonlat", "endlonlat"]].apply(lambda x:
# ----> 3               LineString([x["startlonlat"], x["endlonlat"]]), axis=1)
#
# /usr/local/lib/python3.8/dist-packages/shapely/geometry/linestring.py in __init__(self, coordinates)
#      45         BaseGeometry.__init__(self)
#      46         if coordinates is not None:
# ---> 47             ret = geos_linestring_from_py(coordinates)
#      48             if ret is not None:
#      49                 geom, n = ret
#
# /usr/local/lib/python3.8/dist-packages/shapely/speedups/_speedups.pyx in shapely.speedups._speedups.geos_linestring_from_py()
#
# /usr/local/lib/python3.8/dist-packages/shapely/speedups/_speedups.pyx in shapely.speedups._speedups.geos_linestring_from_py._coords()
#
# /usr/local/lib/python3.8/dist-packages/shapely/coords.py in __getitem__(self, key)
#      83         if isinstance(key, int):
#      84             if self._cseq is None or key + m < 0 or key >= m:
# ---> 85                 raise IndexError("index out of range")
#      86             if key < 0:
#      87                 i = m + key
#
# IndexError: index out of range

# %% [markdown]
# To fix this I explicitly create the function that will be applied and include a try/except condition: this means if the code tries to run but it encounters the specific error I expect, IndexError, it will not crash but instead behave in a different way (create a line between (0,0), and (0,0) )

# %%
def makeline(x, y):
  try: 
    _ = LineString([x, y])
  except IndexError:
    _ =  LineString([(0,0), (0,0)])
  return _

pds[2021][3]["trip"] = pds[2021][3][["startlonlat", "endlonlat"]].apply(lambda x: 
                          makeline(x["startlonlat"], x["endlonlat"]), axis=1)

# %% [markdown]
# ## clean up some data
#
# remove round trips

# %%
#get only the 1-way trips
tripdf = pds[2021][3]
tripdf = tripdf[tripdf["trip_route_category"] == "One Way"]

# %% [markdown]
# remove missing values

# %%
#remove the trips with missing coordinates
tripdf = tripdf[~tripdf["start_lat"].isna()]
tripdf = tripdf[~tripdf["end_lat"].isna()]

# %%
print("the final size of the dataset is (rows, columns)=", tripdf.shape)
# Out:
# the final size of the dataset is (rows, columns)= (269796, 19)

# %% [markdown]
# # mapping and geospatial analysis

# %% [markdown]
# #simple plots with geopandas: I can plot the bike station locations

# %%
#convert the 2021-Q3 data dataframe to a geodataframe
#geodataframes need a "geometry" column to plot
#assign the lat-lon point of trip start to the geometry column
gpds = pds[2021][3]
gpds = gpd.GeoDataFrame(gpds)
gpds["geometry"] = gpds["startlonlat"] # associate the trip trajectories to the geometry in the geodataframe

# %%
ax = gpds.plot()
ax.set_xlabel("longitude (deg)")
ax.set_ylabel("latitude (deg)");

# %% [markdown]
# I can plot the trip trajectories of each trip (takes a while cause its a lot of trips

# %%
#set geometry to the trip column
gpds["geometry"] = gpds["trip"] # associate the trip trajectories to the geometry in the geodataframe

# %% [markdown]
# ## plot the zipcodes of Philly

# %%
# get the zipcode dataframe
zips = gpd.GeoDataFrame.from_file("https://opendata.arcgis.com/api/v3/datasets/b54ec5210cee41c3a884c9086f7af1be_0/downloads/data?format=shp&spatialRefId=4326")
zips.plot(ec = "k", fc="none");

# %%
# what is the coordinate system for the geo data? 
zips.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#set the same coordinate system for the bike trajectories
gpds.crs = zips.crs

# %%
#plot stations over the zip codes map
ax = zips.plot(ec = "k", fc="none")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
gpds["geometry"] = gpds["startlonlat"] # associate the trip trajectories to the geometry in the geodataframe
gpds.plot(ax = ax, alpha=0.1)
ax.set_xlim(xlim)
ax.set_ylim(ylim)

ax.set_xlabel("longitude")
ax.set_ylabel("latitude");

# %%
#plot trip trajectories over the zipcode maps 
ax = zips.plot(ec = "k", fc="none")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
gpds["geometry"] = gpds["trip"] # associate the trip trajectories to the geometry in the geodataframegpds[:100].plot(ax = ax, alpha=0.5)
gpds.plot(ax = ax, alpha=0.5)
ax.set_xlim(xlim)
ax.set_ylim(ylim[0], 40.05);
ax.set_xlabel("longitude")
ax.set_ylabel("latitude");

# %%
#plot trip trajectories over the zipcode maps 
#decrease the transparency to better see the liens
ax = zips.plot(ec = "k", fc="none")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
gpds.plot(ax = ax, alpha=0.005)
ax.set_xlim(xlim)
ax.set_ylim(ylim)

ax.set_xlabel("longitude")
ax.set_ylabel("latitude");

# %% [markdown]
# measure trip length

# %%
#measure trip length
gpds["triplen"] = gpds.geometry.length
gpds.describe()
# Out:
# <ipython-input-32-2a18251cfbbd>:2: UserWarning: Geometry is in a geographic CRS. Results from 'length' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gpds["triplen"] = gpds.geometry.length
#             trip_id       duration  start_station      start_lat  \
# count  3.004320e+05  300432.000000  300432.000000  300412.000000
# mean   4.134962e+08      18.858880    3103.809827      39.952136
# std    8.603314e+06      48.931549      73.620408       0.012410
# min    3.986987e+08       1.000000    3000.000000      39.889938
# 25%    4.058970e+08       7.000000    3040.000000      39.945610
# 50%    4.135417e+08      11.000000    3078.000000      39.951340
# 75%    4.211006e+08      19.000000    3168.000000      39.959240
# max    4.286479e+08    1440.000000    3256.000000      39.991791
#
#            start_lon    end_station        end_lat        end_lon  \
# count  300412.000000  300432.000000  296273.000000  296273.000000
# mean      -75.169267    3102.941684      39.951943     -75.169025
# std         0.016551      74.181687       0.012462       0.016559
# min       -75.226372    3000.000000      39.889938     -75.226372
# 25%       -75.179710    3039.000000      39.945610     -75.179710
# 50%       -75.167831    3077.000000      39.951340     -75.167580
# 75%       -75.158882    3168.000000      39.959229     -75.158211
# max       -75.129936    3256.000000      39.991791     -75.129936
#
#        plan_duration        triplen
# count  300432.000000  300432.000000
# mean       77.623655       0.015699
# std       122.491870       0.011446
# min         1.000000       0.000000
# 25%        30.000000       0.007801
# 50%        30.000000       0.013944
# 75%        30.000000       0.021775
# max       365.000000       0.090212

# %%
#normalize trip lenght
#max of len is .090212
c = cm.viridis(gpds["triplen"] / (0.090212))

# %%
#map color of the trip to trip length
ax = zips.plot(ec = "k", fc="none")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
ax = gpds.plot(ax = ax, alpha=0.002, 
                color = cm.viridis(gpds["triplen"] / (0.090212)))
ax.set_xlim(-75.25, -75.1)
ax.set_ylim(39.880, 40.01)
ax.set_xlabel("longitude")
ax.set_ylabel("latitude");

# %% [markdown]
# ## mapping on top of a map layer

# %% [markdown]
# ### get a leaflet map

# %%
#Define coordinates of where we want to center our map
phl = [39.952583,  -75.165222]

#Create the map
my_map = folium.Map(location=phl, zoom_start=12)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a675531189becd9175bd9cba131c661d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a675531189becd9175bd9cba131c661d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a675531189becd9175bd9cba131c661d = L.map(
#                 &quot;map_a675531189becd9175bd9cba131c661d&quot;,
#                 {
#                     center: [39.952583, -75.165222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6826327a18cd7735b7675e0bbd40b64 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a675531189becd9175bd9cba131c661d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### find the stations' coordinates
#
# Find the individual stations (deduplicate trips that start in the same place)

# %%
stations = gpds.groupby("start_station").first()
stations.head()
# Out:
#                  trip_id  duration      start_time        end_time  start_lat  \
# start_station
# 3000           399093263        37  7/2/2021 15:35  7/2/2021 16:12        NaN
# 3004           398758923        15   7/1/2021 7:41   7/1/2021 7:56  39.953781
# 3005           398698706        11   7/1/2021 1:17   7/1/2021 1:28  39.947330
# 3006           398698703         4   7/1/2021 1:22   7/1/2021 1:26  39.952202
# 3007           398698739         6   7/1/2021 0:14   7/1/2021 0:20  39.945171
#
#                start_lon  end_station    end_lat    end_lon bike_id  \
# start_station
# 3000                 NaN         3157  39.925449 -75.159538   19091
# 3004          -75.163742         3038  39.947811 -75.194092   14690
# 3005          -75.144028         3025  39.937241 -75.161201   14488
# 3006          -75.203110         3208  39.950481 -75.193237   17055
# 3007          -75.159927         3213  39.938869 -75.166634   19676
#
#                plan_duration trip_route_category passholder_type bike_type  \
# start_station
# 3000                     365             One Way       Indego365  electric
# 3004                      30             One Way        Indego30  standard
# 3005                      30             One Way        Indego30  standard
# 3006                      30             One Way        Indego30  electric
# 3007                      30             One Way        Indego30  electric
#
#                start_date                   startlonlat  \
# start_station
# 3000           2021-07-02                   POINT EMPTY
# 3004           2021-07-01  POINT (-75.163742 39.953781)
# 3005           2021-07-01   POINT (-75.144028 39.94733)
# 3006           2021-07-01   POINT (-75.20311 39.952202)
# 3007           2021-07-01  POINT (-75.159927 39.945171)
#
#                                   endlonlat  \
# start_station
# 3000           POINT (-75.159538 39.925449)
# 3004           POINT (-75.194092 39.947811)
# 3005           POINT (-75.161201 39.937241)
# 3006           POINT (-75.193237 39.950481)
# 3007           POINT (-75.166634 39.938869)
#
#                                                             trip  \
# start_station
# 3000                                       LINESTRING (0 0, 0 0)
# 3004           LINESTRING (-75.163742 39.953781, -75.194092 3...
# 3005           LINESTRING (-75.144028 39.94733, -75.161201 39...
# 3006           LINESTRING (-75.20311 39.952202, -75.193237 39...
# 3007           LINESTRING (-75.159927 39.945171, -75.166634 3...
#
#                                                         geometry   triplen
# start_station
# 3000               LINESTRING (0.00000 0.00000, 0.00000 0.00000)  0.000000
# 3004           LINESTRING (-75.16374 39.95378, -75.19409 39.9...  0.030932
# 3005           LINESTRING (-75.14403 39.94733, -75.16120 39.9...  0.019917
# 3006           LINESTRING (-75.20311 39.95220, -75.19324 39.9...  0.010022
# 3007           LINESTRING (-75.15993 39.94517, -75.16663 39.9...  0.009203

# %%
#just in case
stations = stations.dropna()

# %% [markdown]
# the latlon pairs of coordinates in a ```shapely.Point``` object can be extracted with ```Point.x``` and ```Point.y```

# %%
stations.loc[3255, "startlonlat"].x
# Out:
# -75.164383

# %%
my_map = folium.Map(location = phl, zoom_start = 12)


#create the points on the map
for i in stations.index:
  folium.RegularPolygonMarker((stations.loc[i, "start_lat"], 
                               stations.loc[i, "start_lon"]), 
                              popup = "%d"%i, 
                              color = '#00ff40',
                              number_of_sides = 3, 
                              radius = 3).add_to(my_map)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f549d7366f974a69ee2a0f0397c6eaea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f549d7366f974a69ee2a0f0397c6eaea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f549d7366f974a69ee2a0f0397c6eaea = L.map(
#                 &quot;map_f549d7366f974a69ee2a0f0397c6eaea&quot;,
#                 {
#                     center: [39.952583, -75.165222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_adb6b72dcd58be6d39c83488cb61086d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f549d7366f974a69ee2a0f0397c6eaea);
#
#
#             var regular_polygon_marker_59b0df4676d2d8c56c6d0496123b47d6 = new L.RegularPolygonMarker(
#                 [39.953781, -75.163742],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00ff40&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00ff40&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f549d7366f974a69ee2a0f0397c6eaea);
#
#
#         var popup_4d8872583ac8d3042017b137ab93853f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9f52533638afd0020c5c3c98f6c3eea3 = $(`&lt;div id=&quot;html_9f52533638afd0020c5c3c98f6c3eea3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3004&lt;/div&gt;`)[0];
#             popup_4d8872583ac8d3042017b137ab93853f.setContent(html_9f52533638afd0020c5c3c98f6c3eea3);
#
#
#         regular_polygon_marker_59b0df4676d2d8c56c6d0496123b47d6.bindPopup(popup_4d8872583ac8d3042017b137ab93853f)
#         ;
#
#
#
#
#             var regular_polygon_marker_9a9b47c784b6107a75d2b28a105b7ace = new L.RegularPolygonMarker(
#                 [39.94733, -75.144028],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00ff40&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00ff40&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f549d7366f974a69ee2a0f0397c6eaea);
#
#
#         var popup_0587def1947b9c6dab09a49270e84552 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b67ccab85c88312e42f28346240e8eec = $(`&lt;div id=&quot;html_b67ccab85c88312e42f28346240e8eec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3005&lt;/div&gt;`)[0];
#             popup_0587def1947b9c6dab09a49270e84552.setContent(html_b67ccab85c88312e42f28346240e8eec);
#
#
#         regular_polygon_marker_9a9b47c784b6107a75d2b28a105b7ace.bindPopup(popup_0587def1947b9c6dab09a49270e84552)
#         ;
#
#
#
#
#             var regular_polygon_marker_a3d83ad5322f6dfef02020c4761f1326 = new L.RegularPolygonMarker(
#                 [39.952202, -75.20311],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00ff40&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00ff40&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f549d7366f974a69ee2a0f0397c6eaea);
#
#
#         var popup_e778a4c1a90f158cd912d6534a84ee41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a6a57c52911bdf3a26ba3581f230d86f = $(`&lt;div id=&quot;html_a6a57c52911bdf3a26ba3581f230d86f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3006&lt;/div&gt;`)[0];
#             popup_e778a4c1a90f158cd912d6534a84ee41.setContent(html_a6a57c52911bdf3a26ba3581f230d86f);
#
#
#         regular_polygon_marker_a3d83ad5322f6dfef02020c4761f1326.bindPopup(popup_e778a4c1a90f158cd912d6534a84ee41)
#         ;
#
#
#
#
#             var regular_polygon_marker_43d4d6f4628d044a308f07a8ba454a39 = new L.RegularPolygonMarker(
#                 [39.945171, -75.159

# %%
#Create the map
my_map = folium.Map(location = phl, zoom_start = 12)


#create the points on the map and color them by  trip duration for the first trip from that station
#trips that start in that stations

for i in stations.index:
  folium.RegularPolygonMarker((stations.loc[i, "start_lat"], 
                               stations.loc[i, "start_lon"]), 
                              popup = "%d"%i, 
                              fill_color = "0000ff",
                              number_of_sides = 4, 
                              radius = stations.loc[i, "triplen"] / (0.090212) * 3).add_to(my_map)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7548b2c2daa6f54c64f450252c09c56f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7548b2c2daa6f54c64f450252c09c56f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7548b2c2daa6f54c64f450252c09c56f = L.map(
#                 &quot;map_7548b2c2daa6f54c64f450252c09c56f&quot;,
#                 {
#                     center: [39.952583, -75.165222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89e541fe1781661398546453caf81a76 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7548b2c2daa6f54c64f450252c09c56f);
#
#
#             var regular_polygon_marker_5abd00f99ad0c05bcd987c3cd6542d8d = new L.RegularPolygonMarker(
#                 [39.953781, -75.163742],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.0286300801739974, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7548b2c2daa6f54c64f450252c09c56f);
#
#
#         var popup_f80c84ec42ae450ede388afda1f7292f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0ac1da5ce4dea019b42cf6cd86387c30 = $(`&lt;div id=&quot;html_0ac1da5ce4dea019b42cf6cd86387c30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3004&lt;/div&gt;`)[0];
#             popup_f80c84ec42ae450ede388afda1f7292f.setContent(html_0ac1da5ce4dea019b42cf6cd86387c30);
#
#
#         regular_polygon_marker_5abd00f99ad0c05bcd987c3cd6542d8d.bindPopup(popup_f80c84ec42ae450ede388afda1f7292f)
#         ;
#
#
#
#
#             var regular_polygon_marker_f259c4877e980abceebf5f99354ad542 = new L.RegularPolygonMarker(
#                 [39.94733, -75.144028],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.6623506420204585, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7548b2c2daa6f54c64f450252c09c56f);
#
#
#         var popup_14d6b7280e24802fbf978ea091c595c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4c02a728efa4d395b2bc9df2cd0b9755 = $(`&lt;div id=&quot;html_4c02a728efa4d395b2bc9df2cd0b9755&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3005&lt;/div&gt;`)[0];
#             popup_14d6b7280e24802fbf978ea091c595c0.setContent(html_4c02a728efa4d395b2bc9df2cd0b9755);
#
#
#         regular_polygon_marker_f259c4877e980abceebf5f99354ad542.bindPopup(popup_14d6b7280e24802fbf978ea091c595c0)
#         ;
#
#
#
#
#             var regular_polygon_marker_fc611079c702b5202c0b736169fcab02 = new L.RegularPolygonMarker(
#                 [39.952202, -75.20311],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.3332774323309448, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7548b2c2daa6f54c64f450252c09c56f);
#
#
#         var popup_c23c00db4750de2c277085eb543d752c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bb025c9262400c511ffac6954eedef42 = $(`&lt;div id=&quot;html_bb025c9262400c511ffac6954eedef42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3006&lt;/div&gt;`)[0];
#             popup_c23c00db4750de2c277085eb543d752c.setContent(html_bb025c9262400c511ffac6954eedef42);
#
#
#         regular_polygon_marker_fc611079c702b5202c0b736169fcab02.bindPopup(popup_c23c00db4750de2c277085eb543d752c)
#         ;
#
#
#
#
#             var regular_polygon_marker_3f2060883f2f54f4eda09f51a11792b1 = new L.RegularPolyg

# %%
#Create the map
my_map = folium.Map(location = phl, zoom_start = 12)
#change the map background to something more subtle
folium.TileLayer('cartodbpositron').add_to(my_map)


#create the points
for i in stations.index:
  folium.RegularPolygonMarker((stations.loc[i, "start_lat"], 
                               stations.loc[i, "start_lon"]), 
                              popup = "%d"%i, 
                              fill_color = "0000ff",
                              number_of_sides = 4, 
                              radius = stations.loc[i, "triplen"] / (0.090212) * 3).add_to(my_map)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4b21dcf982f1fd28a3f16a597a03be8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4b21dcf982f1fd28a3f16a597a03be8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4b21dcf982f1fd28a3f16a597a03be8 = L.map(
#                 &quot;map_a4b21dcf982f1fd28a3f16a597a03be8&quot;,
#                 {
#                     center: [39.952583, -75.165222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26aec4a62fd34d5bb19f48e51cec3a02 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a4b21dcf982f1fd28a3f16a597a03be8);
#
#
#             var tile_layer_6997bd2a753d52dc656dc16060166ad8 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a4b21dcf982f1fd28a3f16a597a03be8);
#
#
#             var regular_polygon_marker_acc6f1a325b064a4543b3a2de70264d1 = new L.RegularPolygonMarker(
#                 [39.953781, -75.163742],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.0286300801739974, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a4b21dcf982f1fd28a3f16a597a03be8);
#
#
#         var popup_eacfba0171b776eb67d9a92ce478cabe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_19c68774dce5c1939d5a3881b105dc3e = $(`&lt;div id=&quot;html_19c68774dce5c1939d5a3881b105dc3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3004&lt;/div&gt;`)[0];
#             popup_eacfba0171b776eb67d9a92ce478cabe.setContent(html_19c68774dce5c1939d5a3881b105dc3e);
#
#
#         regular_polygon_marker_acc6f1a325b064a4543b3a2de70264d1.bindPopup(popup_eacfba0171b776eb67d9a92ce478cabe)
#         ;
#
#
#
#
#             var regular_polygon_marker_b2c71aa57e0b686165d720a56aff70d2 = new L.RegularPolygonMarker(
#                 [39.94733, -75.144028],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.6623506420204585, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a4b21dcf982f1fd28a3f16a597a03be8);
#
#
#         var popup_14be3ee4f684433d9e7e2335a6434439 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_46b622710be4b66a4c31edde9ab583e0 = $(`&lt;div id=&quot;html_46b622710be4b66a4c31edde9ab583e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3005&lt;/div&gt;`)[0];
#             popup_14be3ee4f684433d9e7e2335a6434439.setContent(html_46b622710be4b66a4c31edde9ab583e0);
#
#
#         regular_polygon_marker_b2c71aa57e0b686165d720a56aff70d2.bindPopup(popup_14be3ee4f684433d9e7e2335a6434439)
#         ;
#
#
#
#
#             var regular_polygon_marker_1b69e5fd4526635b4956cad3fa55c639 = new L.RegularPolygonMarker(
#                 [39.952202, -75.20311],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opa

# %% [markdown]
# ## count the number of trips originating from each station

# %%
origins = gpds.groupby("start_station").count()[["trip_id"]].rename({
    "trip_id":"ntrips"}, axis=1)
origins
# Out:
#                ntrips
# start_station
# 3000               20
# 3004             1325
# 3005             1476
# 3006             2339
# 3007             4742
# ...               ...
# 3252              215
# 3253              217
# 3254               41
# 3255              652
# 3256              145
#
# [168 rows x 1 columns]

# %%
stations = stations.merge(origins, left_index=True, right_index=True)

# %%
print("station with the largest number of trips", stations["ntrips"].max())
# Out:
# station with the largest number of trips 5492

# %%
#Create the map
my_map = folium.Map(location = phl, zoom_start = 12.2)
folium.TileLayer('cartodbpositron').add_to(my_map)

for i in stations.index:
  folium.RegularPolygonMarker((stations.loc[i, "start_lat"], 
                               stations.loc[i, "start_lon"]), 
                              popup = "%d"%i, 
                              color = 
                              matplotlib.colors.rgb2hex(
                                  cm.viridis(stations.loc[i, "ntrips"] / 4750 * 3)),
                              number_of_sides = 10, 
                              radius = stations.loc[i, "triplen"] / .090212 * 3
                              #stations.loc[i, "ntrips"] / 4750 * 3
                              ).add_to(my_map)

#Display the map
print("Citibike stations by popularity (size) and trip length (color)")
my_map
# Out:
# Citibike stations by popularity (size) and trip length (color)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3073f9ec43af041160f0c14da077d30a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3073f9ec43af041160f0c14da077d30a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3073f9ec43af041160f0c14da077d30a = L.map(
#                 &quot;map_3073f9ec43af041160f0c14da077d30a&quot;,
#                 {
#                     center: [39.952583, -75.165222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12.2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b8a90b44c91bf056fb552fcdf16dc92 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3073f9ec43af041160f0c14da077d30a);
#
#
#             var tile_layer_fadd6331a70ca03a06bd98632e026e32 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3073f9ec43af041160f0c14da077d30a);
#
#
#             var regular_polygon_marker_3ba9032188825c244164efe46c5a029b = new L.RegularPolygonMarker(
#                 [39.953781, -75.163742],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#93d741&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#93d741&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 10, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.0286300801739974, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3073f9ec43af041160f0c14da077d30a);
#
#
#         var popup_8fae0db49866b0ebc8c783f8e0a04d90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_20862bf01d75d999be45c432827aa2ba = $(`&lt;div id=&quot;html_20862bf01d75d999be45c432827aa2ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3004&lt;/div&gt;`)[0];
#             popup_8fae0db49866b0ebc8c783f8e0a04d90.setContent(html_20862bf01d75d999be45c432827aa2ba);
#
#
#         regular_polygon_marker_3ba9032188825c244164efe46c5a029b.bindPopup(popup_8fae0db49866b0ebc8c783f8e0a04d90)
#         ;
#
#
#
#
#             var regular_polygon_marker_17f08bc48c9e9aa74b8eea36e9e3dac0 = new L.RegularPolygonMarker(
#                 [39.94733, -75.144028],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d2e21b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#d2e21b&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 10, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.6623506420204585, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3073f9ec43af041160f0c14da077d30a);
#
#
#         var popup_abdb2925a799a0dec3cd2ed3d03c286a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7da1dca4b02cca11d797651b3e61951f = $(`&lt;div id=&quot;html_7da1dca4b02cca11d797651b3e61951f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3005&lt;/div&gt;`)[0];
#             popup_abdb2925a799a0dec3cd2ed3d03c286a.setContent(html_7da1dca4b02cca11d797651b3e61951f);
#
#
#         regular_polygon_marker_17f08bc48c9e9aa74b8eea36e9e3dac0.bindPopup(popup_abdb2925a799a0dec3cd2ed3d03c286a)
#         ;
#
#
#
#
#             var regular_polygon_marker_07029a9ef703c98627c0036aee2f7395 = new L.RegularPolygonMarker(
#                 [39.952202, -75.20311],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fde725&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 10

# %% [markdown]
# ## Find the most popular bike

# %%
bikes = gpds.groupby("bike_id").count()
print("bike id for bike with most trips:", bikes["trip_id"].max())
# Out:
# bike id for bike with most trips: 294

# %%
#pick the most popular bike
most_pop_bike = bikes[bikes["trip_id"] == 294].index[0]

# %%
gpds[gpds.bike_id == most_pop_bike].head()
# Out:
#         trip_id  duration      start_time        end_time  start_station  \
# 811   398795312         8  7/1/2021 11:39  7/1/2021 11:47           3123
# 1130  398830342        21  7/1/2021 15:35  7/1/2021 15:56           3075
# 1767  398960611         9  7/1/2021 21:40  7/1/2021 21:49           3046
# 2562  399070125        91  7/2/2021 12:15  7/2/2021 13:46           3213
# 3525  399100864         8  7/2/2021 17:33  7/2/2021 17:41           3046
#
#       start_lat  start_lon  end_station    end_lat    end_lon  ...  \
# 811   39.980042 -75.170883         3075  39.967178 -75.161247  ...
# 1130  39.967178 -75.161247         3046  39.950119 -75.144722  ...
# 1767  39.950119 -75.144722         3213  39.938869 -75.166634  ...
# 2562  39.938869 -75.166634         3046  39.950119 -75.144722  ...
# 3525  39.950119 -75.144722         3185  39.951691 -75.158882  ...
#
#      plan_duration  trip_route_category passholder_type bike_type  start_date  \
# 811             30              One Way        Indego30  electric  2021-07-01
# 1130            30              One Way        Indego30  electric  2021-07-01
# 1767            30              One Way        Indego30  electric  2021-07-01
# 2562            30              One Way        Indego30  electric  2021-07-02
# 3525            30              One Way        Indego30  electric  2021-07-02
#
#                        startlonlat                     endlonlat  \
# 811   POINT (-75.170883 39.980042)  POINT (-75.161247 39.967178)
# 1130  POINT (-75.161247 39.967178)  POINT (-75.144722 39.950119)
# 1767  POINT (-75.144722 39.950119)  POINT (-75.166634 39.938869)
# 2562  POINT (-75.166634 39.938869)  POINT (-75.144722 39.950119)
# 3525  POINT (-75.144722 39.950119)  POINT (-75.158882 39.951691)
#
#                                                    trip  \
# 811   LINESTRING (-75.170883 39.980042, -75.161247 3...
# 1130  LINESTRING (-75.161247 39.967178, -75.144722 3...
# 1767  LINESTRING (-75.144722 39.950119, -75.166634 3...
# 2562  LINESTRING (-75.166634 39.938869, -75.144722 3...
# 3525  LINESTRING (-75.144722 39.950119, -75.158882 3...
#
#                                                geometry   triplen
# 811   LINESTRING (-75.17088 39.98004, -75.16125 39.9...  0.016073
# 1130  LINESTRING (-75.16125 39.96718, -75.14472 39.9...  0.023750
# 1767  LINESTRING (-75.14472 39.95012, -75.16663 39.9...  0.024631
# 2562  LINESTRING (-75.16663 39.93887, -75.14472 39.9...  0.024631
# 3525  LINESTRING (-75.14472 39.95012, -75.15888 39.9...  0.014247
#
# [5 rows x 21 columns]

# %%
# plot the trips of the most popular bike
ax = zips.plot(ec = "k", fc="none")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
gpds[gpds.bike_id == most_pop_bike].plot(ax = ax, alpha=0.5, 
                color = cm.viridis(gpds["triplen"] / (0.090212)))
ax.set_xlim(-75.25, -75.1)
ax.set_ylim(39.880, 40.01);

# %%
#Create the map
my_map = folium.Map(location = phl, zoom_start = 12)

folium.TileLayer('cartodbpositron').add_to(my_map)

#plot the trip trajectories of the most popular bike
for i in stations.index:
  folium.PolyLine(((stations.loc[i, "start_lat"], 
                               stations.loc[i, "start_lon"]), 
                   (stations.loc[i, "end_lat"], 
                               stations.loc[i, "end_lon"])), 
                              popup = "%d"%i, 
                              opacity=0.5,
                              color = matplotlib.colors.rgb2hex(
                                  cm.viridis(stations.loc[i, "triplen"] / .090212)),
                              weight=1).add_to(my_map)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe505c547f8c2ac4c51d17a657dec6d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe505c547f8c2ac4c51d17a657dec6d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe505c547f8c2ac4c51d17a657dec6d3 = L.map(
#                 &quot;map_fe505c547f8c2ac4c51d17a657dec6d3&quot;,
#                 {
#                     center: [39.952583, -75.165222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6cfbe204bc99e1bee41845c1be7798b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe505c547f8c2ac4c51d17a657dec6d3);
#
#
#             var tile_layer_c1157ff02d4a113734e3e1c64efdf50b = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe505c547f8c2ac4c51d17a657dec6d3);
#
#
#             var poly_line_d093bb2522b1c1eca2e135fc708191d3 = L.polyline(
#                 [[39.953781, -75.163742], [39.947811, -75.194092]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#306a8e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#306a8e&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_fe505c547f8c2ac4c51d17a657dec6d3);
#
#
#         var popup_c6e3eaacc376b364d83ebe3eecfc43e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_75ddab0a6f207bb7cac5a9be52e38cec = $(`&lt;div id=&quot;html_75ddab0a6f207bb7cac5a9be52e38cec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3004&lt;/div&gt;`)[0];
#             popup_c6e3eaacc376b364d83ebe3eecfc43e7.setContent(html_75ddab0a6f207bb7cac5a9be52e38cec);
#
#
#         poly_line_d093bb2522b1c1eca2e135fc708191d3.bindPopup(popup_c6e3eaacc376b364d83ebe3eecfc43e7)
#         ;
#
#
#
#
#             var poly_line_d34b0de4a614b790c02d1edaf41c54db = L.polyline(
#                 [[39.94733, -75.144028], [39.937241, -75.161201]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3e4989&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3e4989&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_fe505c547f8c2ac4c51d17a657dec6d3);
#
#
#         var popup_8fe6582a01f478a77cdce7e2b446277e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_960f51d321b09d0b0b6b766332f6f36c = $(`&lt;div id=&quot;html_960f51d321b09d0b0b6b766332f6f36c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3005&lt;/div&gt;`)[0];
#             popup_8fe6582a01f478a77cdce7e2b446277e.setContent(html_960f51d321b09d0b0b6b766332f6f36c);
#
#
#         poly_line_d34b0de4a614b790c02d1edaf41c54db.bindPopup(popup_8fe6582a01f478a77cdce7e2b446277e)
#         ;
#
#
#
#
#             var poly_line_5608669eade5a14f3cb86882ce664026 = L.polyline(
#                 [[39.952202, -75.20311], [39.950481, -75.193237]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#482878&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#482878&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_fe505c547f8c2ac4c51d17a657dec6d3);
#
#
#         var popup_7b3fbd08eec51d47869e8e32ccbbf128 = L.popup({&quot
